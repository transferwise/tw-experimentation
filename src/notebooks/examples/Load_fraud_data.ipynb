# %%
from typing import Iterable
import glob
import datetime
import copy
import os, sys

import pandas as pd
import numpy as np

from clickhouse_driver import Client

root_path = os.path.realpath("../../../..")
sys.path.append(os.path.join(root_path, "clickhouse_utils/src"))

from clickhouse_utils.schema import initialize_schema

# %%
# define all the constants
data_dir = os.path.join(root_path, "event_model/data") + "/"

host = "172.31.50.194"
port = 9000
http_port = 8123

database_name = "fraud"
table_name = "fraud"

order_by = ("USER_ID","DATE_CREATED")
high_cardinality = []

start_date = datetime.date(2021, 1, 1)
end_date = datetime.date(2021, 4, 21)

# %%
# the 'Ethinicity' column is mislableled, and actually describes nationality, ie citizen of what state the client is
data = pd.read_csv(data_dir + f"{table_name}/fraud-2021-03.csv").rename(columns={'ETHNICITY':'NATIONALITY'})
data['DATE_CREATED'] = pd.to_datetime(data['DATE_CREATED'])

# %%
display(data.head())
display(data.dtypes)
display(len(data))
# Out:
#     USER_ID NATIONALITY               DATE_CREATED STATE
# 0  23569214          \N 2021-03-16 15:39:42.393340   NEW
# 1  23569214         aus 2021-03-24 15:21:49.007797   NEW
# 2  23569214         aus 2021-03-28 16:34:32.318904   NEW
# 3  23523345          \N 2021-03-01 07:15:25.019546   NEW
# 4  23523345          \N 2021-03-02 07:08:10.525745   NEW
# USER_ID                  int64
# NATIONALITY             object
# DATE_CREATED    datetime64[ns]
# STATE                   object
# dtype: object
# 23677329

# %%
# create the schema, inferring it from dataframe
client = Client(host=host, port=port)

# read in a sample dataframe to create the schema
initialize_schema(
    client,
    database_name=database_name,
    table_name=table_name,
    dtypes=data.dtypes,
    order_by = order_by,
    high_cardinality= high_cardinality,
    flush_table=True,
)
# Out:
#                 CREATE TABLE IF NOT EXISTS fraud.fraud
#                 (
#                     `USER_ID` Int64,
#     `NATIONALITY` LowCardinality(String),
#     `DATE_CREATED` DateTime64(3),
#     `STATE` LowCardinality(String)
#                 )
#                 ENGINE = MergeTree()
#                 ORDER BY (`USER_ID`, `DATE_CREATED`)

# %%
# %%time
# insert the data into the table we just created
# NOTE: THIS GOES MUCH MUCH FASTER FROM EG CSV FILES USING THE CLICKHOUSE COMMAND_LINE CLIENT
# THIS IS FOR DEMONSTRATION ONLY
from sqlalchemy import create_engine
import datetime

ch_url = f"clickhouse+native://{host}/{database_name}"
ch_engine = create_engine(ch_url, echo=False)

print(datetime.datetime.now())
for i in range(6):
    print(i)
    df = data.to_sql('fraud', ch_engine, if_exists='append', index=False)
    print(datetime.datetime.now())
# Out:
# 2021-04-23 11:18:21.769130
# 0
# 2021-04-23 11:23:52.222982
# 1
# 2021-04-23 11:29:28.760455
# 2
# 2021-04-23 11:35:01.619369
# 3
# 2021-04-23 11:40:35.517196
# 4
# 2021-04-23 11:46:13.329757
# 5
# 2021-04-23 11:51:45.334687
# CPU times: user 32min 23s, sys: 1min, total: 33min 24s
# Wall time: 33min 23s

# %%
client.execute(f"select count(*) from  {database_name}.{table_name}")
# Out:
# [(189418632,)]

# %%
# %%time
# check that the table is there
group_col = "USER_ID"
client.execute(f"select {group_col}, count(*) as cnt from {database_name}.{table_name} group by {group_col}  order by cnt desc limit 100")
# Out:
# CPU times: user 4.81 ms, sys: 155 µs, total: 4.97 ms
# Wall time: 951 ms
# [(21059557, 1869592),
#  (6240973, 1614712),
#  (22415010, 1099024),
#  (5568329, 351640),
#  (24824103, 318992),
#  (6152280, 218048),
#  (2450920, 210104),
#  (23134279, 184192),
#  (6266878, 147944),
#  (11071443, 134928),
#  (18192710, 123384),
#  (23126505, 106368),
#  (61227, 99352),
#  (15547762, 85936),
#  (6844989, 77312),
#  (25245086, 67024),
#  (23892293, 64912),
#  (4432876, 63848),
#  (11971884, 63000),
#  (20793030, 52864),
#  (17773356, 50448),
#  (10892492, 50016),
#  (9728530, 48640),
#  (19736173, 48088),
#  (13097884, 47808),
#  (4694060, 47176),
#  (5487273, 46504),
#  (15504265, 42912),
#  (25177266, 42512),
#  (4167573, 41920),
#  (5838, 41512),
#  (9533832, 40536),
#  (21866717, 40168),
#  (17566639, 36192),
#  (9591155, 33552),
#  (18686410, 31352),
#  (14649629, 31128),
#  (8970975, 30752),
#  (4483753, 30720),
#  (21171350, 28168),
#  (4644110, 27808),
#  (22886891, 26320),
#  (15073285, 25672),
#  (14053381, 25608),
#  (14660671, 24816),
#  (20486714, 24256),
#  (24142812, 24120),
#  (20360098, 23664),
#  (7479446, 23656),
#  (7069414, 22616),
#  (12034306, 22488),
#  (2892200, 22432),
#  (9383251, 22304),
#  (5821456, 22216),
#  (7682215, 22112),
#  (20410390, 21568),
#  (10049854, 21232),
#  (2226758, 20936),
#  (1101041, 20488),
#  (9121504, 20176),
#  (15705549, 19960),
#  (24720906, 19712),
#  (25243569, 19384),
#  (2438051, 19208),
#  (26469819, 18832),
#  (6764600, 18824),
#  (26502011, 18808),
#  (23611687, 18704),
#  (23019621, 17776),
#  (6251290, 17640),
#  (4919711, 17424),
#  (19546318, 17368),
#  (173393, 17128),
#  (10085421, 17072),
#  (23019230, 16960),
#  (23504393, 16608),
#  (12771235, 16520),
#  (20892361, 16432),
#  (356365, 16352),
#  (25250546, 15984),
#  (5534784, 15720),
#  (2162166, 15496),
#  (17978589, 15448),
#  (3042688, 14600),
#  (14793425, 14576),
#  (24705183, 14504),
#  (7971675, 14496),
#  (26370067, 14432),
#  (17729075, 14376),
#  (17723289, 14344),
#  (25327408, 14296),
#  (8284966, 14216),
#  (20121379, 14200),
#  (18620648, 14144),
#  (20603684, 14096),
#  (20909604, 14080),
#  (1848064, 13928),
#  (23488080, 13904),
#  (19569951, 13872),
#  (14211306, 13640)]

# %%
# %%time
# check that the table is there
group_col = "NATIONALITY, STATE"
client.execute(f"select {group_col}, count(*) as cnt from {database_name}.{table_name} group by {group_col}  order by cnt desc")
# Out:
# CPU times: user 7.79 ms, sys: 251 µs, total: 8.05 ms
# Wall time: 2.65 s
# [('\\N', 'NEW', 104385384),
#  ('\\N', 'APPROVED', 14527736),
#  ('bra', 'NEW', 9360176),
#  ('aus', 'NEW', 8416288),
#  ('deu', 'NEW', 6299800),
#  ('ind', 'NEW', 6043936),
#  ('esp', 'NEW', 4615992),
#  ('fra', 'NEW', 4345160),
#  ('ita', 'NEW', 2756568),
#  ('tur', 'NEW', 1685064),
#  ('sgp', 'NEW', 1522712),
#  ('jpn', 'NEW', 1439232),
#  ('aus', 'APPROVED', 1218912),
#  ('hun', 'NEW', 1171952),
#  ('pol', 'NEW', 1151560),
#  ('bra', 'APPROVED', 1026512),
#  ('dnk', 'NEW', 897792),
#  ('pak', 'NEW', 844720),
#  ('rou', 'NEW', 838392),
#  ('ind', 'APPROVED', 779464),
#  ('deu', 'APPROVED', 756864),
#  ('bgr', 'NEW', 725352),
#  ('nld', 'NEW', 720856),
#  ('chn', 'NEW', 706488),
#  ('ukr', 'NEW', 690032),
#  ('\\N', 'FRAUD', 672760),
#  ('idn', 'NEW', 638632),
#  ('esp', 'APPROVED', 623712),
#  ('fra', 'APPROVED', 611128),
#  ('cze', 'NEW', 608112),
#  ('nga', 'NEW', 516792),
#  ('mys', 'NEW', 510152),
#  ('irl', 'NEW', 475568),
#  ('tha', 'NEW', 406024),
#  ('hkg', 'NEW', 343624),
#  ('ita', 'APPROVED', 341760),
#  ('ukr', 'APPROVED', 301280),
#  ('phl', 'NEW', 282744),
#  ('swe', 'NEW', 233392),
#  ('tur', 'APPROVED', 230760),
#  ('rus', 'NEW', 225752),
#  ('grc', 'NEW', 210984),
#  ('jpn', 'APPROVED', 204480),
#  ('ltu', 'NEW', 195512),
#  ('bgd', 'NEW', 162240),
#  ('nga', 'APPROVED', 159528),
#  ('sgp', 'APPROVED', 158160),
#  ('dnk', 'APPROVED', 154096),
#  ('kor', 'NEW', 153088),
#  ('bgr', 'APPROVED', 149248),
#  ('rou', 'APPROVED', 148072),
#  ('pol', 'APPROVED', 146664),
#  ('pak', 'APPROVED', 143824),
#  ('\\N', 'REVIEW_PENDING', 138864),
#  ('hun', 'APPROVED', 134776),
#  ('can', 'NEW', 120264),
#  ('hrv', 'NEW', 118192),
#  ('vnm', 'NEW', 116096),
#  ('bel', 'NEW', 106800),
#  ('\\N', 'AUTO_APPROVED', 104752),
#  ('geo', 'NEW', 102496),
#  ('chn', 'APPROVED', 94712),
#  ('idn', 'APPROVED', 92672),
#  ('fin', 'NEW', 87936),
#  ('nld', 'APPROVED', 85480),
#  ('est', 'NEW', 84352),
#  ('cze', 'APPROVED', 81680),
#  ('\\N', 'HIGH_RISK', 80064),
#  ('srb', 'NEW', 79440),
#  ('mys', 'APPROVED', 75808),
#  ('lva', 'NEW', 70040),
#  ('ken', 'NEW', 64680),
#  ('aus', 'FRAUD', 63168),
#  ('\\N', 'MONITORING', 61008),
#  ('swe', 'APPROVED', 58840),
#  ('irl', 'APPROVED', 52472),
#  ('gha', 'NEW', 51696),
#  ('rus', 'APPROVED', 51056),
#  ('phl', 'APPROVED', 43912),
#  ('bra', 'FRAUD', 43408),
#  ('mex', 'NEW', 39208),
#  ('svk', 'NEW', 37088),
#  ('ind', 'FRAUD', 36432),
#  ('cyp', 'NEW', 34512),
#  ('tha', 'APPROVED', 31368),
#  ('hkg', 'APPROVED', 31056),
#  ('grc', 'APPROVED', 30176),
#  ('esp', 'FRAUD', 30136),
#  ('nor', 'NEW', 29536),
#  ('ltu', 'APPROVED', 29536),
#  ('fra', 'FRAUD', 28616),
#  ('deu', 'FRAUD', 26712),
#  ('zaf', 'NEW', 24936),
#  ('egy', 'NEW', 21504),
#  ('bgd', 'APPROVED', 21432),
#  ('che', 'NEW', 21056),
#  ('aze', 'NEW', 21056),
#  ('can', 'APPROVED', 18056),
#  ('kor', 'APPROVED', 17544),
#  ('aus', 'AUTO_APPROVED', 16152),
#  ('hrv', 'APPROVED', 15344),
#  ('ita', 'FRAUD', 15248),
#  ('aus', 'REVIEW_PENDING', 13912),
#  ('gha', 'APPROVED', 13784),
#  ('bel', 'APPROVED', 12912),
#  ('ken', 'APPROVED', 12408),
#  ('geo', 'APPROVED', 12208),
#  ('est', 'APPROVED', 12016),
#  ('rou', 'FRAUD', 11656),
#  ('nga', 'FRAUD', 11520),
#  ('bra', 'REVIEW_PENDING', 11504),
#  ('bra', 'AUTO_APPROVED', 11024),
#  ('npl', 'NEW', 10896),
#  ('ind', 'REVIEW_PENDING', 10864),
#  ('jpn', 'FRAUD', 10768),
#  ('twn', 'NEW', 10728),
#  ('lva', 'APPROVED', 10616),
#  ('pak', 'FRAUD', 10104),
#  ('fra', 'REVIEW_PENDING', 9552),
#  ('mmr', 'NEW', 9536),
#  ('isr', 'NEW', 9488),
#  ('esp', 'REVIEW_PENDING', 9424),
#  ('tur', 'FRAUD', 9392),
#  ('vnm', 'APPROVED', 9176),
#  ('srb', 'APPROVED', 8992),
#  ('mlt', 'NEW', 8528),
#  ('deu', 'REVIEW_PENDING', 8472),
#  ('bgd', 'FRAUD', 8416),
#  ('fin', 'APPROVED', 8360),
#  ('pol', 'FRAUD', 7976),
#  ('mex', 'APPROVED', 7816),
#  ('alb', 'NEW', 7752),
#  ('dnk', 'FRAUD', 7720),
#  ('prt', 'NEW', 6296),
#  ('idn', 'FRAUD', 5768),
#  ('arg', 'NEW', 5744),
#  ('aus', 'MONITORING', 5640),
#  ('aus', 'HIGH_RISK', 5512),
#  ('sgp', 'FRAUD', 5504),
#  ('ind', 'HIGH_RISK', 5336),
#  ('deu', 'HIGH_RISK', 5320),
#  ('mar', 'NEW', 5224),
#  ('cze', 'FRAUD', 5128),
#  ('mys', 'FRAUD', 5120),
#  ('chn', 'FRAUD', 4968),
#  ('nor', 'APPROVED', 4960),
#  ('esp', 'AUTO_APPROVED', 4936),
#  ('isl', 'NEW', 4720),
#  ('bgr', 'FRAUD', 4696),
#  ('cyp', 'APPROVED', 4688),
#  ('are', 'NEW', 4616),
#  ('svk', 'APPROVED', 4608),
#  ('mdv', 'NEW', 4552),
#  ('hun', 'FRAUD', 4512),
#  ('fra', 'AUTO_APPROVED', 4432),
#  ('ind', 'AUTO_APPROVED', 4312),
#  ('isr', 'APPROVED', 4280),
#  ('ita', 'REVIEW_PENDING', 4152),
#  ('svn', 'NEW', 4128),
#  ('deu', 'AUTO_APPROVED', 3888),
#  ('bra', 'MONITORING', 3832),
#  ('per', 'NEW', 3752),
#  ('aze', 'APPROVED', 3728),
#  ('deu', 'MONITORING', 3552),
#  ('aut', 'NEW', 3528),
#  ('ind', 'MONITORING', 3488),
#  ('col', 'NEW', 3312),
#  ('zaf', 'APPROVED', 3192),
#  ('irl', 'FRAUD', 3152),
#  ('nga', 'REVIEW_PENDING', 3072),
#  ('ukr', 'FRAUD', 3040),
#  ('jor', 'NEW', 3016),
#  ('esp', 'MONITORING', 2888),
#  ('esp', 'HIGH_RISK', 2816),
#  ('che', 'APPROVED', 2800),
#  ('bra', 'HIGH_RISK', 2784),
#  ('nld', 'FRAUD', 2720),
#  ('ita', 'AUTO_APPROVED', 2704),
#  ('ltu', 'FRAUD', 2560),
#  ('sau', 'NEW', 2496),
#  ('jpn', 'REVIEW_PENDING', 2480),
#  ('zwe', 'NEW', 2472),
#  ('egy', 'APPROVED', 2464),
#  ('fra', 'HIGH_RISK', 2456),
#  ('npl', 'APPROVED', 2336),
#  ('fra', 'MONITORING', 2240),
#  ('tur', 'REVIEW_PENDING', 2176),
#  ('lva', 'FRAUD', 2016),
#  ('nzl', 'NEW', 2000),
#  ('pak', 'REVIEW_PENDING', 1920),
#  ('chn', 'REVIEW_PENDING', 1880),
#  ('sgp', 'REVIEW_PENDING', 1848),
#  ('ita', 'HIGH_RISK', 1776),
#  ('bgr', 'REVIEW_PENDING', 1680),
#  ('gha', 'FRAUD', 1616),
#  ('idn', 'REVIEW_PENDING', 1592),
#  ('twn', 'APPROVED', 1592),
#  ('rou', 'REVIEW_PENDING', 1584),
#  ('ukr', 'REVIEW_PENDING', 1568),
#  ('xkx', 'NEW', 1560),
#  ('ita', 'MONITORING', 1536),
#  ('jor', 'APPROVED', 1520),
#  ('mys', 'REVIEW_PENDING', 1520),
#  ('dnk', 'REVIEW_PENDING', 1504),
#  ('hun', 'REVIEW_PENDING', 1504),
#  ('mmr', 'APPROVED', 1496),
#  ('rus', 'FRAUD', 1392),
#  ('bih', 'NEW', 1376),
#  ('nga', 'AUTO_APPROVED', 1336),
#  ('mda', 'NEW', 1288),
#  ('col', 'APPROVED', 1232),
#  ('lbn', 'NEW', 1232),
#  ('mng', 'NEW', 1216),
#  ('alb', 'APPROVED', 1216),
#  ('pak', 'HIGH_RISK', 1216),
#  ('swe', 'FRAUD', 1208),
#  ('phl', 'FRAUD', 1136),
#  ('hun', 'HIGH_RISK', 1128),
#  ('sgp', 'MONITORING', 1072),
#  ('dnk', 'AUTO_APPROVED', 1032),
#  ('hkg', 'FRAUD', 1016),
#  ('mlt', 'APPROVED', 1016),
#  ('jpn', 'HIGH_RISK', 1008),
#  ('cze', 'REVIEW_PENDING', 984),
#  ('jpn', 'AUTO_APPROVED', 960),
#  ('grc', 'FRAUD', 952),
#  ('tur', 'AUTO_APPROVED', 944),
#  ('nga', 'HIGH_RISK', 936),
#  ('vnm', 'FRAUD', 896),
#  ('pak', 'AUTO_APPROVED', 872),
#  ('chn', 'AUTO_APPROVED', 856),
#  ('blr', 'NEW', 848),
#  ('pol', 'MONITORING', 832),
#  ('nld', 'AUTO_APPROVED', 824),
#  ('mar', 'APPROVED', 792),
#  ('arg', 'APPROVED', 784),
#  ('jpn', 'MONITORING', 784),
#  ('tur', 'HIGH_RISK', 768),
#  ('rou', 'AUTO_APPROVED', 768),
#  ('hun', 'MONITORING', 752),
#  ('bgr', 'AUTO_APPROVED', 744),
#  ('tur', 'MONITORING', 736),
#  ('geo', 'FRAUD', 728),
#  ('irl', 'REVIEW_PENDING', 712),
#  ('ukr', 'MONITORING', 712),
#  ('isl', 'APPROVED', 696),
#  ('kwt', 'NEW', 696),
#  ('sgp', 'AUTO_APPROVED', 680),
#  ('gha', 'REVIEW_PENDING', 680),
#  ('pol', 'REVIEW_PENDING', 680),
#  ('irl', 'AUTO_APPROVED', 672),
#  ('idn', 'AUTO_APPROVED', 656),
#  ('hun', 'AUTO_APPROVED', 648),
#  ('dnk', 'MONITORING', 648),
#  ('rou', 'HIGH_RISK', 624),
#  ('ken', 'FRAUD', 616),
#  ('are', 'APPROVED', 616),
#  ('kor', 'FRAUD', 600),
#  ('bel', 'FRAUD', 592),
#  ('mdv', 'APPROVED', 592),
#  ('nld', 'REVIEW_PENDING', 584),
#  ('nzl', 'APPROVED', 568),
#  ('pak', 'MONITORING', 560),
#  ('bgd', 'REVIEW_PENDING', 560),
#  ('tha', 'FRAUD', 552),
#  ('ltu', 'REVIEW_PENDING', 536),
#  ('rou', 'MONITORING', 528),
#  ('ken', 'HIGH_RISK', 528),
#  ('svn', 'APPROVED', 520),
#  ('mys', 'MONITORING', 520),
#  ('hrv', 'FRAUD', 512),
#  ('sgp', 'HIGH_RISK', 512),
#  ('cyp', 'FRAUD', 512),
#  ('mex', 'FRAUD', 504),
#  ('idn', 'MONITORING', 504),
#  ('pol', 'AUTO_APPROVED', 480),
#  ('tha', 'AUTO_APPROVED', 480),
#  ('zwe', 'APPROVED', 472),
#  ('cze', 'AUTO_APPROVED', 472),
#  ('\\N', 'REVIEW', 456),
#  ('hkg', 'MONITORING', 456),
#  ('dnk', 'HIGH_RISK', 416),
#  ('xkx', 'APPROVED', 416),
#  ('bgd', 'MONITORING', 416),
#  ('nga', 'MONITORING', 416),
#  ('uga', 'NEW', 408),
#  ('bgr', 'HIGH_RISK', 400),
#  ('prt', 'APPROVED', 392),
#  ('mys', 'AUTO_APPROVED', 392),
#  ('grc', 'AUTO_APPROVED', 352),
#  ('phl', 'REVIEW_PENDING', 336),
#  ('bgr', 'MONITORING', 328),
#  ('est', 'FRAUD', 328),
#  ('ukr', 'AUTO_APPROVED', 328),
#  ('swe', 'HIGH_RISK', 320),
#  ('nld', 'MONITORING', 320),
#  ('grc', 'REVIEW_PENDING', 312),
#  ('sau', 'APPROVED', 304),
#  ('per', 'APPROVED', 304),
#  ('cmr', 'NEW', 304),
#  ('rus', 'REVIEW_PENDING', 296),
#  ('lao', 'NEW', 288),
#  ('pol', 'HIGH_RISK', 280),
#  ('est', 'AUTO_APPROVED', 280),
#  ('lbn', 'APPROVED', 280),
#  ('can', 'FRAUD', 272),
#  ('srb', 'FRAUD', 272),
#  ('hkg', 'HIGH_RISK', 264),
#  ('mkd', 'NEW', 264),
#  ('hkg', 'REVIEW_PENDING', 264),
#  ('rus', 'AUTO_APPROVED', 264),
#  ('srb', 'REVIEW_PENDING', 264),
#  ('ukr', 'HIGH_RISK', 256),
#  ('ken', 'REVIEW_PENDING', 256),
#  ('cze', 'MONITORING', 248),
#  ('rus', 'MONITORING', 232),
#  ('vnm', 'REVIEW_PENDING', 232),
#  ('zmb', 'NEW', 232),
#  ('mex', 'REVIEW_PENDING', 232),
#  ('mda', 'APPROVED', 224),
#  ('fin', 'FRAUD', 224),
#  ('chl', 'NEW', 224),
#  ('hrv', 'REVIEW_PENDING', 224),
#  ('lva', 'REVIEW_PENDING', 216),
#  ('zmb', 'APPROVED', 216),
#  ('idn', 'HIGH_RISK', 208),
#  ('ltu', 'AUTO_APPROVED', 208),
#  ('chn', 'MONITORING', 208),
#  ('phl', 'AUTO_APPROVED', 200),
#  ('gha', 'AUTO_APPROVED', 200),
#  ('gha', 'HIGH_RISK', 200),
#  ('rus', 'HIGH_RISK', 200),
#  ('swe', 'MONITORING', 192),
#  ('irl', 'MONITORING', 192),
#  ('lva', 'HIGH_RISK', 184),
#  ('est', 'REVIEW_PENDING', 176),
#  ('bgd', 'AUTO_APPROVED', 168),
#  ('kor', 'MONITORING', 168),
#  ('alb', 'FRAUD', 168),
#  ('aut', 'APPROVED', 160),
#  ('cze', 'HIGH_RISK', 160),
#  ('kor', 'HIGH_RISK', 152),
#  ('nor', 'FRAUD', 152),
#  ('fin', 'REVIEW_PENDING', 144),
#  ('mng', 'APPROVED', 144),
#  ('ken', 'MONITORING', 136),
#  ('ltu', 'MONITORING', 128),
#  ('aze', 'FRAUD', 128),
#  ('nld', 'HIGH_RISK', 128),
#  ('kor', 'REVIEW_PENDING', 128),
#  ('geo', 'AUTO_APPROVED', 128),
#  ('kor', 'AUTO_APPROVED', 128),
#  ('swe', 'REVIEW_PENDING', 120),
#  ('egy', 'FRAUD', 120),
#  ('deu', 'REVIEW', 120),
#  ('rus', 'REVIEW', 112),
#  ('uga', 'APPROVED', 112),
#  ('tha', 'MONITORING', 112),
#  ('hkg', 'AUTO_APPROVED', 112),
#  ('irl', 'HIGH_RISK', 104),
#  ('bgd', 'HIGH_RISK', 104),
#  ('est', 'MONITORING', 96),
#  ('srb', 'HIGH_RISK', 96),
#  ('zaf', 'REVIEW_PENDING', 88),
#  ('eth', 'NEW', 88),
#  ('vnm', 'MONITORING', 80),
#  ('aze', 'REVIEW_PENDING', 80),
#  ('phl', 'MONITORING', 80),
#  ('chn', 'HIGH_RISK', 80),
#  ('bel', 'REVIEW_PENDING', 80),
#  ('xkx', 'FRAUD', 72),
#  ('bih', 'APPROVED', 72),
#  ('per', 'FRAUD', 72),
#  ('nor', 'AUTO_APPROVED', 72),
#  ('geo', 'REVIEW_PENDING', 72),
#  ('kgz', 'NEW', 72),
#  ('ltu', 'HIGH_RISK', 72),
#  ('srb', 'MONITORING', 64),
#  ('bel', 'AUTO_APPROVED', 64),
#  ('mdv', 'REVIEW_PENDING', 64),
#  ('arg', 'REVIEW_PENDING', 56),
#  ('mex', 'HIGH_RISK', 56),
#  ('gha', 'MONITORING', 56),
#  ('hrv', 'HIGH_RISK', 56),
#  ('hrv', 'MONITORING', 56),
#  ('col', 'MONITORING', 56),
#  ('can', 'MONITORING', 56),
#  ('lva', 'AUTO_APPROVED', 56),
#  ('mdv', 'FRAUD', 48),
#  ('mys', 'HIGH_RISK', 48),
#  ('mex', 'AUTO_APPROVED', 48),
#  ('nor', 'REVIEW_PENDING', 48),
#  ('phl', 'HIGH_RISK', 48),
#  ('vnm', 'HIGH_RISK', 48),
#  ('kwt', 'APPROVED', 48),
#  ('can', 'AUTO_APPROVED', 48),
#  ('alb', 'REVIEW_PENDING', 48),
#  ('mkd', 'APPROVED', 48),
#  ('sau', 'REVIEW_PENDING', 48),
#  ('tha', 'REVIEW_PENDING', 40),
#  ('srb', 'AUTO_APPROVED', 40),
#  ('nor', 'MONITORING', 40),
#  ('can', 'REVIEW_PENDING', 40),
#  ('npl', 'AUTO_APPROVED', 40),
#  ('fin', 'AUTO_APPROVED', 40),
#  ('geo', 'MONITORING', 32),
#  ('egy', 'AUTO_APPROVED', 32),
#  ('grc', 'MONITORING', 32),
#  ('twn', 'REVIEW_PENDING', 32),
#  ('zaf', 'FRAUD', 32),
#  ('svk', 'FRAUD', 32),
#  ('mar', 'FRAUD', 32),
#  ('aze', 'MONITORING', 32),
#  ('npl', 'HIGH_RISK', 32),
#  ('alb', 'MONITORING', 24),
#  ('lbn', 'AUTO_APPROVED', 24),
#  ('jor', 'FRAUD', 24),
#  ('mng', 'REVIEW_PENDING', 24),
#  ('isl', 'AUTO_APPROVED', 24),
#  ('che', 'REVIEW_PENDING', 24),
#  ('blr', 'APPROVED', 24),
#  ('cmr', 'APPROVED', 24),
#  ('zaf', 'AUTO_APPROVED', 16),
#  ('che', 'FRAUD', 16),
#  ('zwe', 'FRAUD', 16),
#  ('fin', 'MONITORING', 16),
#  ('hrv', 'AUTO_APPROVED', 16),
#  ('uga', 'HIGH_RISK', 16),
#  ('npl', 'MONITORING', 16),
#  ('xkx', 'REVIEW_PENDING', 16),
#  ('chl', 'APPROVED', 16),
#  ('swe', 'AUTO_APPROVED', 16),
#  ('svk', 'REVIEW_PENDING', 16),
#  ('vnm', 'AUTO_APPROVED', 16),
#  ('grc', 'HIGH_RISK', 16),
#  ('twn', 'HIGH_RISK', 16),
#  ('mmr', 'HIGH_RISK', 16),
#  ('tha', 'HIGH_RISK', 16),
#  ('fin', 'HIGH_RISK', 16),
#  ('isr', 'REVIEW_PENDING', 16),
#  ('jor', 'REVIEW_PENDING', 8),
#  ('mdv', 'MONITORING', 8),
#  ('lao', 'REVIEW_PENDING', 8),
#  ('\\N', '\\N', 8),
#  ('\\N', 'FPF', 8)]

# %%
# sys.path.append(os.path.join(root_path, "ml_utils/src"))
# sys.path.append(
#     os.path.join(root_path, "analysts-airflow/workspace-analysts/plugins/")
# )
# from snowflake_utils.local_snowflake_wrapper import LocalSnowflakeWrapper
# from ml_utils.data.query import caching_query

# %%
# def data_for_date(db_io, date: datetime.date) -> pd.DataFrame:
#     query = f"""
#         SELECT td.user_id, td.input_data:recipientNameEthnicity::STRING, td.date_created, us.state
#     FROM public_smurfs_clear.transfer_data td
#     LEFT JOIN fraud_state.user_state us ON us.user_id = td.user_id
#     WHERE td.date_created::date = '{date}';
#     """
#     return db_io.fetch(query)

# %%
# # get the data, store it in daily zipped segments - only need to do it the first time round

# db_io = LocalSnowflakeWrapper("egor.kraev@transferwise.com")

# this_date = copy.copy(end_date)

# while this_date >= start_date:
#     this_df = caching_query(
#         data_dir + f"{table_name}/{table_name}_{this_date}.zip",
#         lambda: data_for_date(db_io, this_date),
#     )
#     if this_date == start_date:
#         display(this_df.head().T)
#     this_date -= datetime.timedelta(days=1)
# from clickhouse_utils.inserter import files_to_df_iterable, clickhouse_insert_dataframes
